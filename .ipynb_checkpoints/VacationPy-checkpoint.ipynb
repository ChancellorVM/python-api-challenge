# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv
import geoviews.feature as gf
from geoviews import opts
import holoviews as hv

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="cbe177d9-26ba-4b14-a83e-3bd506eb587d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0                  albany  42.6001  -73.9662     -0.43        86
# 1        1                   kapit   2.0167  112.9333     22.91        99
# 2        2             west island -12.1568   96.8225     27.99        94
# 3        3  hawaiian paradise park  19.5933 -154.9731     17.16        77
# 4        4           blackmans bay -43.0167  147.3167     21.07        88
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        1.10      US  1738594244
# 1          83        0.45      MY  1738594696
# 2          75        3.60      CC  1738594654
# 3          75        3.09      US  1738594698
# 4           0        2.42      AU  1738594653

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points(
    x="Lng", y="Lat", geo=True, tiles="OSM", 
    size="Humidity", color="Humidity", 
    cmap="coolwarm", hover_cols=["City"]
)

# Display the map
city_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df[
    (city_data_df["Max Temp"] > 21) &
    (city_data_df["Max Temp"] < 27) &
    (city_data_df["Wind Speed"] < 4.5) &
    (city_data_df["Cloudiness"] == 0)
].dropna()

# Display sample data
ideal_cities_df.head()
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 4          4   blackmans bay -43.0167  147.3167     21.07        88
# 15        15        hermanus -34.4187   19.2345     25.45        63
# 43        43     port alfred -33.5906   26.8910     25.10        73
# 105      105  port elizabeth -33.9180   25.5701     25.73        65
# 117      117           myeik  12.4333   98.6000     25.04        76
#
#      Cloudiness  Wind Speed Country        Date
# 4             0        2.42      AU  1738594653
# 15            0        4.36      ZA  1738594711
# 43            0        2.24      ZA  1738594742
# 105           0        2.24      ZA  1738594811
# 117           0        1.81      MM  1738594825

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 4     blackmans bay      AU -43.0167  147.3167        88
# 15         hermanus      ZA -34.4187   19.2345        63
# 43      port alfred      ZA -33.5906   26.8910        73
# 105  port elizabeth      ZA -33.9180   25.5701        65
# 117           myeik      MM  12.4333   98.6000        76

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Define search radius (10,000 meters)
radius = 10000  

# Print status update
print("Starting hotel search...")

# Iterate through cities and search for hotels
for index, row in hotel_df.iterrows():
    lat, lng = row["Lat"], row["Lng"]
    
    # Define API request parameters
    params = {
        "categories": "accommodation.hotel",
        "bias": f"proximity:{lng},{lat}",
        "filter": f"circle:{lng},{lat},{radius}",
        "limit": 1,
        "apiKey": geoapify_key
    }
    
    # Make API request
    response = requests.get("https://api.geoapify.com/v2/places", params=params).json()
    
    # Try to extract hotel name, otherwise set as "No hotel found"
    try:
        hotel_df.loc[index, "Hotel Name"] = response["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log search result
    print(f"{hotel_df.loc[index, 'City']} - Nearest Hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display updated DataFrame
hotel_df.head()
# Out:
# Starting hotel search...
# blackmans bay - Nearest Hotel: Villa Howden
# hermanus - Nearest Hotel: Aloe guest house
# port alfred - Nearest Hotel: No hotel found
# port elizabeth - Nearest Hotel: Waterford Hotel
# myeik - Nearest Hotel: Green Eyes Hotel
# reggane - Nearest Hotel: No hotel found
# pisco - Nearest Hotel: La Portada
# santiago - Nearest Hotel: apart arturo prat
# callao - Nearest Hotel: Casa Ronald
# acapulco de juarez - Nearest Hotel: Hotel del Valle
# tindouf - Nearest Hotel: محمد بوسبي
# khon buri - Nearest Hotel: The tree
#                City Country      Lat       Lng  Humidity        Hotel Name
# 4     blackmans bay      AU -43.0167  147.3167        88      Villa Howden
# 15         hermanus      ZA -34.4187   19.2345        63  Aloe guest house
# 43      port alfred      ZA -33.5906   26.8910        73    No hotel found
# 105  port elizabeth      ZA -33.9180   25.5701        65   Waterford Hotel
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    x="Lng", y="Lat", geo=True, tiles="OSM", 
    size=100, color="blue", hover_cols=["City", "Hotel Name"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name)
